# %% [markdown]
# ## Another cool API . . . but this time you're on your own 😓
#
# Philadelphia, like many other cities makes a valiant effort to open source as much data as possible.
#
# Using [this](https://www.opendataphilly.org/) website, go answer the following questions:
# - What was the most common crime in Philadelphia between 2019 and now?

# %%
#do your imports here

import pandas as pd
import requests
import json

# %%
#call the API to pull in the data

response = requests.get("https://phl.carto.com/api/v2/sql?q=SELECT * FROM incidents_part1_part2 WHERE dispatch_date_time >= '2019-01-01'")

# %%
#load the response's content

content = response.content

# %%
#load the content into JSON

loaded = json.loads(content)

# %%
#explore the JSON to see what the data looks like

loaded
# Out:
# {'rows': [{'cartodb_id': 38,
#    'the_geom': '0101000020E610000031D3D5A143C452C07341A64A4E064440',
#    'the_geom_webmercator': '0101000020110F0000EEF40FB386E05FC1BAFD11F4E3965241',
#    'objectid': 13,
#    'dc_dist': '9',
#    'psa': '1',
#    'dispatch_date_time': '2019-11-12T09:59:00Z',
#    'dispatch_date': '2019-11-12',
#    'dispatch_time': '09:59:00',
#    'hour_': 9,
#    'dc_key': '201909047628',
#    'location_block': '100 BLOCK S BROAD ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.06662794,
#    'point_y': 40.04926427},
#   {'cartodb_id': 46,
#    'the_geom': '0101000020E6100000CE175A2155CA52C0779E57C02DFB4340',
#    'the_geom_webmercator': '0101000020110F00009EBBEA78D5EA5FC11055888E8D8A5241',
#    'objectid': 21,
#    'dc_dist': '9',
#    'psa': '2',
#    'dispatch_date_time': '2019-01-19T17:20:00Z',
#    'dispatch_date': '2019-01-19',
#    'dispatch_time': '17:20:00',
#    'hour_': 17,
#    'dc_key': '201909002506',
#    'location_block': '1400 BLOCK SPRING GARDEN ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16144594,
#    'point_y': 39.96233372},
#   {'cartodb_id': 47,
#    'the_geom': '0101000020E6100000CE175A2155CA52C0779E57C02DFB4340',
#    'the_geom_webmercator': '0101000020110F00009EBBEA78D5EA5FC11055888E8D8A5241',
#    'objectid': 22,
#    'dc_dist': '9',
#    'psa': '2',
#    'dispatch_date_time': '2020-03-25T18:32:00Z',
#    'dispatch_date': '2020-03-25',
#    'dispatch_time': '18:32:00',
#    'hour_': 18,
#    'dc_key': '202009012094',
#    'location_block': '1400 BLOCK SPRING GARDEN ST',
#    'ucr_general': '600',
#    'text_general_code': 'Theft from Vehicle',
#    'point_x': -75.16144594,
#    'point_y': 39.96233372},
#   {'cartodb_id': 91,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 66,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-03-08T19:08:00Z',
#    'dispatch_date': '2020-03-08',
#    'dispatch_time': '19:08:00',
#    'hour_': 19,
#    'dc_key': '202077001196',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 92,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 67,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-03-15T18:41:00Z',
#    'dispatch_date': '2020-03-15',
#    'dispatch_time': '18:41:00',
#    'hour_': 18,
#    'dc_key': '202077001312',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 93,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 68,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-03-18T08:17:00Z',
#    'dispatch_date': '2020-03-18',
#    'dispatch_time': '08:17:00',
#    'hour_': 8,
#    'dc_key': '202077001343',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 94,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 69,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-04-03T15:32:33Z',
#    'dispatch_date': '2020-04-03',
#    'dispatch_time': '15:32:33',
#    'hour_': 15,
#    'dc_key': '202077001460',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 95,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 70,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-02-11T09:39:00Z',
#    'dispatch_date': '2020-02-11',
#    'dispatch_time': '09:39:00',
#    'hour_': 9,
#    'dc_key': '202077000675',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 96,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 71,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-02-24T13:28:00Z',
#    'dispatch_date': '2020-02-24',
#    'dispatch_time': '13:28:00',
#    'hour_': 13,
#    'dc_key': '202077000951',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 97,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 72,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-02-27T11:40:00Z',
#    'dispatch_date': '2020-02-27',
#    'dispatch_time': '11:40:00',
#    'hour_': 11,
#    'dc_key': '202077000986',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 98,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 73,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-03-05T16:14:00Z',
#    'dispatch_date': '2020-03-05',
#    'dispatch_time': '16:14:00',
#    'hour_': 16,
#    'dc_key': '202077001142',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 99,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 74,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-03-06T15:15:00Z',
#    'dispatch_date': '2020-03-06',
#    'dispatch_time': '15:15:00',
#    'hour_': 15,
#    'dc_key': '202077001163',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 100,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 75,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-03-07T19:01:00Z',
#    'dispatch_date': '2020-03-07',
#    'dispatch_time': '19:01:00',
#    'hour_': 19,
#    'dc_key': '202077001182',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 101,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 76,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-12-14T08:07:00Z',
#    'dispatch_date': '2019-12-14',
#    'dispatch_time': '08:07:00',
#    'hour_': 8,
#    'dc_key': '201977007047',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 102,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 77,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-12-24T14:03:00Z',
#    'dispatch_date': '2019-12-24',
#    'dispatch_time': '14:03:00',
#    'hour_': 14,
#    'dc_key': '201977007242',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 103,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 78,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-12-25T16:29:00Z',
#    'dispatch_date': '2019-12-25',
#    'dispatch_time': '16:29:00',
#    'hour_': 16,
#    'dc_key': '201977007257',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 104,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 79,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-01-13T14:43:00Z',
#    'dispatch_date': '2020-01-13',
#    'dispatch_time': '14:43:00',
#    'hour_': 14,
#    'dc_key': '202077000209',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 105,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 80,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-01-30T09:24:00Z',
#    'dispatch_date': '2020-01-30',
#    'dispatch_time': '09:24:00',
#    'hour_': 9,
#    'dc_key': '202077000483',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 106,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 81,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2020-02-09T16:33:00Z',
#    'dispatch_date': '2020-02-09',
#    'dispatch_time': '16:33:00',
#    'hour_': 16,
#    'dc_key': '202077000650',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 107,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 82,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-11-06T17:56:00Z',
#    'dispatch_date': '2019-11-06',
#    'dispatch_time': '17:56:00',
#    'hour_': 17,
#    'dc_key': '201977006300',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 113,
#    'the_geom': '0101000020E61000001EDC42FC68CA52C0EF931FC82CF94340',
#    'the_geom_webmercator': '0101000020110F000094F0BF32F7EA5FC1A5BBF33655885241',
#    'objectid': 88,
#    'dc_dist': '6',
#    'psa': '3',
#    'dispatch_date_time': '2019-08-23T21:42:00Z',
#    'dispatch_date': '2019-08-23',
#    'dispatch_time': '21:42:00',
#    'hour_': 21,
#    'dc_key': '201906042575',
#    'location_block': '300 BLOCK S 13TH ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.1626578,
#    'point_y': 39.94667913},
#   {'cartodb_id': 114,
#    'the_geom': '0101000020E61000001EDC42FC68CA52C0EF931FC82CF94340',
#    'the_geom_webmercator': '0101000020110F000094F0BF32F7EA5FC1A5BBF33655885241',
#    'objectid': 89,
#    'dc_dist': '6',
#    'psa': '3',
#    'dispatch_date_time': '2019-11-20T17:34:00Z',
#    'dispatch_date': '2019-11-20',
#    'dispatch_time': '17:34:00',
#    'hour_': 17,
#    'dc_key': '201906060378',
#    'location_block': '300 BLOCK S 13TH ST',
#    'ucr_general': '600',
#    'text_general_code': 'Theft from Vehicle',
#    'point_x': -75.1626578,
#    'point_y': 39.94667913},
#   {'cartodb_id': 119,
#    'the_geom': '0101000020E61000006D7893428DC852C0EAFFA01E70024440',
#    'the_geom_webmercator': '0101000020110F0000AC2B8221CFE75FC18EE6FC9D99925241',
#    'objectid': 94,
#    'dc_dist': '25',
#    'psa': '2',
#    'dispatch_date_time': '2019-07-22T00:30:00Z',
#    'dispatch_date': '2019-07-22',
#    'dispatch_time': '00:30:00',
#    'hour_': 0,
#    'dc_key': '201925059777',
#    'location_block': '400 BLOCK CASKEY ST',
#    'ucr_general': '400',
#    'text_general_code': 'Aggravated Assault No Firearm',
#    'point_x': -75.13362183,
#    'point_y': 40.01904662},
#   {'cartodb_id': 129,
#    'the_geom': '0101000020E6100000EA77405D0DC952C016F8ED98F8FA4340',
#    'the_geom_webmercator': '0101000020110F000080BB90BAA8E85FC1EC88B8A8528A5241',
#    'objectid': 104,
#    'dc_dist': '6',
#    'psa': '1',
#    'dispatch_date_time': '2019-06-23T17:44:00Z',
#    'dispatch_date': '2019-06-23',
#    'dispatch_time': '17:44:00',
#    'hour_': 17,
#    'dc_key': '201906030139',
#    'location_block': 'N 2ND ST / SPRING GARDEN ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.14144069,
#    'point_y': 39.96071159},
#   {'cartodb_id': 160,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 217,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-07-09T08:18:00Z',
#    'dispatch_date': '2019-07-09',
#    'dispatch_time': '08:18:00',
#    'hour_': 8,
#    'dc_key': '201977003797',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 161,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 305,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-10-10T15:36:00Z',
#    'dispatch_date': '2019-10-10',
#    'dispatch_time': '15:36:00',
#    'hour_': 15,
#    'dc_key': '201977005736',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 162,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 306,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-10-14T10:47:00Z',
#    'dispatch_date': '2019-10-14',
#    'dispatch_time': '10:47:00',
#    'hour_': 10,
#    'dc_key': '201977005823',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 163,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 307,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-10-21T09:42:00Z',
#    'dispatch_date': '2019-10-21',
#    'dispatch_time': '09:42:00',
#    'hour_': 9,
#    'dc_key': '201977005947',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 164,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 308,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-10-21T10:07:00Z',
#    'dispatch_date': '2019-10-21',
#    'dispatch_time': '10:07:00',
#    'hour_': 10,
#    'dc_key': '201977005949',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 165,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 309,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-10-21T10:18:00Z',
#    'dispatch_date': '2019-10-21',
#    'dispatch_time': '10:18:00',
#    'hour_': 10,
#    'dc_key': '201977005951',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 166,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 310,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-12T16:20:00Z',
#    'dispatch_date': '2019-09-12',
#    'dispatch_time': '16:20:00',
#    'hour_': 16,
#    'dc_key': '201977005175',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 167,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 311,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-13T17:14:00Z',
#    'dispatch_date': '2019-09-13',
#    'dispatch_time': '17:14:00',
#    'hour_': 17,
#    'dc_key': '201977005213',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 168,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 312,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-14T15:54:00Z',
#    'dispatch_date': '2019-09-14',
#    'dispatch_time': '15:54:00',
#    'hour_': 15,
#    'dc_key': '201977005234',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 169,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 313,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-15T18:35:00Z',
#    'dispatch_date': '2019-09-15',
#    'dispatch_time': '18:35:00',
#    'hour_': 18,
#    'dc_key': '201977005246',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 170,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 314,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-19T09:29:00Z',
#    'dispatch_date': '2019-09-19',
#    'dispatch_time': '09:29:00',
#    'hour_': 9,
#    'dc_key': '201977005316',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 171,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 315,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-20T07:54:00Z',
#    'dispatch_date': '2019-09-20',
#    'dispatch_time': '07:54:00',
#    'hour_': 7,
#    'dc_key': '201977005330',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 172,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 316,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-08-24T10:27:00Z',
#    'dispatch_date': '2019-08-24',
#    'dispatch_time': '10:27:00',
#    'hour_': 10,
#    'dc_key': '201977004831',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 173,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 317,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-05T17:36:00Z',
#    'dispatch_date': '2019-09-05',
#    'dispatch_time': '17:36:00',
#    'hour_': 17,
#    'dc_key': '201977005062',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Theft from Vehicle',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 174,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 318,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-05T21:05:00Z',
#    'dispatch_date': '2019-09-05',
#    'dispatch_time': '21:05:00',
#    'hour_': 21,
#    'dc_key': '201977005066',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 175,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 319,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-06T17:26:00Z',
#    'dispatch_date': '2019-09-06',
#    'dispatch_time': '17:26:00',
#    'hour_': 17,
#    'dc_key': '201977005084',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 176,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 320,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-08T17:27:00Z',
#    'dispatch_date': '2019-09-08',
#    'dispatch_time': '17:27:00',
#    'hour_': 17,
#    'dc_key': '201977005116',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 177,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 321,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-09-12T14:08:00Z',
#    'dispatch_date': '2019-09-12',
#    'dispatch_time': '14:08:00',
#    'hour_': 14,
#    'dc_key': '201977005172',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 178,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 322,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-07-15T20:54:00Z',
#    'dispatch_date': '2019-07-15',
#    'dispatch_time': '20:54:00',
#    'hour_': 20,
#    'dc_key': '201977003935',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 179,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 323,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-07-16T15:21:00Z',
#    'dispatch_date': '2019-07-16',
#    'dispatch_time': '15:21:00',
#    'hour_': 15,
#    'dc_key': '201977003949',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 180,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 324,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-07-25T00:21:00Z',
#    'dispatch_date': '2019-07-25',
#    'dispatch_time': '00:21:00',
#    'hour_': 0,
#    'dc_key': '201977004158',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 181,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 325,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-07-31T07:03:00Z',
#    'dispatch_date': '2019-07-31',
#    'dispatch_time': '07:03:00',
#    'hour_': 7,
#    'dc_key': '201977004277',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 182,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 326,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-08-07T12:06:00Z',
#    'dispatch_date': '2019-08-07',
#    'dispatch_time': '12:06:00',
#    'hour_': 12,
#    'dc_key': '201977004454',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 183,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 327,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-08-19T19:53:00Z',
#    'dispatch_date': '2019-08-19',
#    'dispatch_time': '19:53:00',
#    'hour_': 19,
#    'dc_key': '201977004738',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 184,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 328,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-06-29T15:04:00Z',
#    'dispatch_date': '2019-06-29',
#    'dispatch_time': '15:04:00',
#    'hour_': 15,
#    'dc_key': '201977003592',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 185,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 329,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-06-29T17:34:00Z',
#    'dispatch_date': '2019-06-29',
#    'dispatch_time': '17:34:00',
#    'hour_': 17,
#    'dc_key': '201977003597',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 186,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 330,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-06-29T22:21:00Z',
#    'dispatch_date': '2019-06-29',
#    'dispatch_time': '22:21:00',
#    'hour_': 22,
#    'dc_key': '201977003605',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 187,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 331,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-07-03T11:57:00Z',
#    'dispatch_date': '2019-07-03',
#    'dispatch_time': '11:57:00',
#    'hour_': 11,
#    'dc_key': '201977003679',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 188,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 332,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-07-05T12:28:00Z',
#    'dispatch_date': '2019-07-05',
#    'dispatch_time': '12:28:00',
#    'hour_': 12,
#    'dc_key': '201977003705',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 219,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 218,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-06-02T18:37:00Z',
#    'dispatch_date': '2019-06-02',
#    'dispatch_time': '18:37:00',
#    'hour_': 18,
#    'dc_key': '201977002991',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 220,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 219,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-06-03T19:26:00Z',
#    'dispatch_date': '2019-06-03',
#    'dispatch_time': '19:26:00',
#    'hour_': 19,
#    'dc_key': '201977003018',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 221,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 220,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-06-08T09:08:00Z',
#    'dispatch_date': '2019-06-08',
#    'dispatch_time': '09:08:00',
#    'hour_': 9,
#    'dc_key': '201977003091',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 222,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 221,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-06-09T07:45:00Z',
#    'dispatch_date': '2019-06-09',
#    'dispatch_time': '07:45:00',
#    'hour_': 7,
#    'dc_key': '201977003106',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 223,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 222,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-06-14T10:25:00Z',
#    'dispatch_date': '2019-06-14',
#    'dispatch_time': '10:25:00',
#    'hour_': 10,
#    'dc_key': '201977003233',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 224,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 223,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-06-28T14:47:00Z',
#    'dispatch_date': '2019-06-28',
#    'dispatch_time': '14:47:00',
#    'hour_': 14,
#    'dc_key': '201977003576',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 225,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 224,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-05-18T09:15:00Z',
#    'dispatch_date': '2019-05-18',
#    'dispatch_time': '09:15:00',
#    'hour_': 9,
#    'dc_key': '201977002642',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 226,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 225,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-05-19T12:48:00Z',
#    'dispatch_date': '2019-05-19',
#    'dispatch_time': '12:48:00',
#    'hour_': 12,
#    'dc_key': '201977002671',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 227,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 226,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-05-20T13:02:00Z',
#    'dispatch_date': '2019-05-20',
#    'dispatch_time': '13:02:00',
#    'hour_': 13,
#    'dc_key': '201977002710',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 228,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 227,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-05-22T13:42:00Z',
#    'dispatch_date': '2019-05-22',
#    'dispatch_time': '13:42:00',
#    'hour_': 13,
#    'dc_key': '201977002758',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 229,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 228,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-05-24T14:18:00Z',
#    'dispatch_date': '2019-05-24',
#    'dispatch_time': '14:18:00',
#    'hour_': 14,
#    'dc_key': '201977002802',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 230,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 229,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-05-26T16:33:00Z',
#    'dispatch_date': '2019-05-26',
#    'dispatch_time': '16:33:00',
#    'hour_': 16,
#    'dc_key': '201977002843',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 231,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 230,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-04-16T07:47:00Z',
#    'dispatch_date': '2019-04-16',
#    'dispatch_time': '07:47:00',
#    'hour_': 7,
#    'dc_key': '201977001969',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 232,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 231,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-04-25T12:42:00Z',
#    'dispatch_date': '2019-04-25',
#    'dispatch_time': '12:42:00',
#    'hour_': 12,
#    'dc_key': '201977002159',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 233,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 232,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-04-30T16:36:00Z',
#    'dispatch_date': '2019-04-30',
#    'dispatch_time': '16:36:00',
#    'hour_': 16,
#    'dc_key': '201977002251',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 234,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 233,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-05-05T15:04:00Z',
#    'dispatch_date': '2019-05-05',
#    'dispatch_time': '15:04:00',
#    'hour_': 15,
#    'dc_key': '201977002356',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 235,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 234,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-05-07T15:42:00Z',
#    'dispatch_date': '2019-05-07',
#    'dispatch_time': '15:42:00',
#    'hour_': 15,
#    'dc_key': '201977002434',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 236,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 235,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-05-07T17:50:00Z',
#    'dispatch_date': '2019-05-07',
#    'dispatch_time': '17:50:00',
#    'hour_': 17,
#    'dc_key': '201977002439',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 237,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 236,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-03-04T09:43:00Z',
#    'dispatch_date': '2019-03-04',
#    'dispatch_time': '09:43:00',
#    'hour_': 9,
#    'dc_key': '201977001113',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 238,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 237,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-03-04T13:02:00Z',
#    'dispatch_date': '2019-03-04',
#    'dispatch_time': '13:02:00',
#    'hour_': 13,
#    'dc_key': '201977001117',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 239,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 238,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-03-16T20:07:00Z',
#    'dispatch_date': '2019-03-16',
#    'dispatch_time': '20:07:00',
#    'hour_': 20,
#    'dc_key': '201977001360',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '400',
#    'text_general_code': 'Aggravated Assault No Firearm',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 240,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 239,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-04-04T19:48:00Z',
#    'dispatch_date': '2019-04-04',
#    'dispatch_time': '19:48:00',
#    'hour_': 19,
#    'dc_key': '201977001733',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 241,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 240,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-04-11T14:20:00Z',
#    'dispatch_date': '2019-04-11',
#    'dispatch_time': '14:20:00',
#    'hour_': 14,
#    'dc_key': '201977001875',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 242,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 241,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-04-12T20:02:00Z',
#    'dispatch_date': '2019-04-12',
#    'dispatch_time': '20:02:00',
#    'hour_': 20,
#    'dc_key': '201977001901',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '400',
#    'text_general_code': 'Aggravated Assault No Firearm',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 243,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 242,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-02-15T15:37:00Z',
#    'dispatch_date': '2019-02-15',
#    'dispatch_time': '15:37:00',
#    'hour_': 15,
#    'dc_key': '201977000775',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 244,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 243,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-02-17T21:32:00Z',
#    'dispatch_date': '2019-02-17',
#    'dispatch_time': '21:32:00',
#    'hour_': 21,
#    'dc_key': '201977000826',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '500',
#    'text_general_code': 'Burglary Residential',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 245,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 244,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-02-18T17:05:00Z',
#    'dispatch_date': '2019-02-18',
#    'dispatch_time': '17:05:00',
#    'hour_': 17,
#    'dc_key': '201977000837',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 246,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 245,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-02-24T09:35:00Z',
#    'dispatch_date': '2019-02-24',
#    'dispatch_time': '09:35:00',
#    'hour_': 9,
#    'dc_key': '201977000933',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 294,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 293,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-11-16T09:32:00Z',
#    'dispatch_date': '2019-11-16',
#    'dispatch_time': '09:32:00',
#    'hour_': 9,
#    'dc_key': '201977006451',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 295,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 294,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-12-05T08:50:00Z',
#    'dispatch_date': '2019-12-05',
#    'dispatch_time': '08:50:00',
#    'hour_': 8,
#    'dc_key': '201977006875',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 296,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 295,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-12-06T11:43:00Z',
#    'dispatch_date': '2019-12-06',
#    'dispatch_time': '11:43:00',
#    'hour_': 11,
#    'dc_key': '201977006900',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 297,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 296,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-12-08T11:56:00Z',
#    'dispatch_date': '2019-12-08',
#    'dispatch_time': '11:56:00',
#    'hour_': 11,
#    'dc_key': '201977006935',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 298,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 297,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-12-12T11:45:00Z',
#    'dispatch_date': '2019-12-12',
#    'dispatch_time': '11:45:00',
#    'hour_': 11,
#    'dc_key': '201977006992',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 299,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 298,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-10-24T08:31:00Z',
#    'dispatch_date': '2019-10-24',
#    'dispatch_time': '08:31:00',
#    'hour_': 8,
#    'dc_key': '201977006032',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 300,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
#    'objectid': 299,
#    'dc_dist': '77',
#    'psa': 'A',
#    'dispatch_date_time': '2019-10-28T18:53:00Z',
#    'dispatch_date': '2019-10-28',
#    'dispatch_time': '18:53:00',
#    'hour_': 18,
#    'dc_key': '201977006109',
#    'location_block': '0 BLOCK PIA WAY',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.23070645,
#    'point_y': 39.88388114},
#   {'cartodb_id': 301,
#    'the_geom': '0101000020E61000007B6EFCE4C3CE52C0F4EC660423F14340',
#    'the_geom_webmercator': '0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F5241',
# ...
#   {'cartodb_id': 10868,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12459,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-06-09T16:38:00Z',
#    'dispatch_date': '2019-06-09',
#    'dispatch_time': '16:38:00',
#    'hour_': 16,
#    'dc_key': '201939048043',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10869,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12460,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-06-09T17:37:00Z',
#    'dispatch_date': '2019-06-09',
#    'dispatch_time': '17:37:00',
#    'hour_': 17,
#    'dc_key': '201939048055',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10870,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12461,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-07-09T17:00:00Z',
#    'dispatch_date': '2019-07-09',
#    'dispatch_time': '17:00:00',
#    'hour_': 17,
#    'dc_key': '201939057773',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '400',
#    'text_general_code': 'Aggravated Assault No Firearm',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10871,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12462,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-08-09T18:24:00Z',
#    'dispatch_date': '2019-08-09',
#    'dispatch_time': '18:24:00',
#    'hour_': 18,
#    'dc_key': '201939068824',
#    'location_block': '2100 BLOCK W LEHIGH AV',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10872,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12463,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-02-06T17:28:00Z',
#    'dispatch_date': '2019-02-06',
#    'dispatch_time': '17:28:00',
#    'hour_': 17,
#    'dc_key': '201939011447',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10873,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12464,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-02-16T13:00:00Z',
#    'dispatch_date': '2019-02-16',
#    'dispatch_time': '13:00:00',
#    'hour_': 13,
#    'dc_key': '201939014262',
#    'location_block': '2100 BLOCK W LEHIGH AV',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10874,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12465,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-03-13T15:45:00Z',
#    'dispatch_date': '2019-03-13',
#    'dispatch_time': '15:45:00',
#    'hour_': 15,
#    'dc_key': '201939021493',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10875,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12466,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-04-03T12:48:00Z',
#    'dispatch_date': '2019-04-03',
#    'dispatch_time': '12:48:00',
#    'hour_': 12,
#    'dc_key': '201939027439',
#    'location_block': '2100 BLOCK W LEHIGH AV',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10876,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12467,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-04-06T09:24:00Z',
#    'dispatch_date': '2019-04-06',
#    'dispatch_time': '09:24:00',
#    'hour_': 9,
#    'dc_key': '201939028294',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10877,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12468,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-05-06T13:57:00Z',
#    'dispatch_date': '2019-05-06',
#    'dispatch_time': '13:57:00',
#    'hour_': 13,
#    'dc_key': '201939036693',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10893,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12855,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-09-01T19:06:00Z',
#    'dispatch_date': '2019-09-01',
#    'dispatch_time': '19:06:00',
#    'hour_': 19,
#    'dc_key': '201939075854',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10894,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12856,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-09-10T13:59:00Z',
#    'dispatch_date': '2019-09-10',
#    'dispatch_time': '13:59:00',
#    'hour_': 13,
#    'dc_key': '201939078576',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10895,
#    'the_geom': '0101000020E6100000C7ADB452A9CA52C06763E3C987FF4340',
#    'the_geom_webmercator': '0101000020110F00003113757B64EB5FC1D15C134C608F5241',
#    'objectid': 12857,
#    'dc_dist': '39',
#    'psa': '3',
#    'dispatch_date_time': '2019-10-09T09:54:00Z',
#    'dispatch_date': '2019-10-09',
#    'dispatch_time': '09:54:00',
#    'hour_': 9,
#    'dc_key': '201939087465',
#    'location_block': '2100 BLOCK W LEHIGH AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.16658466,
#    'point_y': 39.99633144},
#   {'cartodb_id': 10897,
#    'the_geom': '0101000020E6100000389F9D8064C852C09E96FEA9E1FE4340',
#    'the_geom_webmercator': '0101000020110F00000C7B60E689E75FC160CB6922A88E5241',
#    'objectid': 12859,
#    'dc_dist': '25',
#    'psa': '3',
#    'dispatch_date_time': '2019-09-20T20:29:00Z',
#    'dispatch_date': '2019-09-20',
#    'dispatch_time': '20:29:00',
#    'hour_': 20,
#    'dc_key': '201925076456',
#    'location_block': '100 BLOCK W LEHIGH AV',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.13113417,
#    'point_y': 39.99126172},
#   {'cartodb_id': 10898,
#    'the_geom': '0101000020E6100000389F9D8064C852C09E96FEA9E1FE4340',
#    'the_geom_webmercator': '0101000020110F00000C7B60E689E75FC160CB6922A88E5241',
#    'objectid': 12860,
#    'dc_dist': '25',
#    'psa': '3',
#    'dispatch_date_time': '2020-02-23T19:53:00Z',
#    'dispatch_date': '2020-02-23',
#    'dispatch_time': '19:53:00',
#    'hour_': 19,
#    'dc_key': '202025013083',
#    'location_block': '100 BLOCK W LEHIGH AV',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.13113417,
#    'point_y': 39.99126172},
#   {'cartodb_id': 10899,
#    'the_geom': '0101000020E6100000675A6AD6BCC352C0437F57BAF1024440',
#    'the_geom_webmercator': '0101000020110F0000E3C2BCBCA1DF5FC1FA13195B29935241',
#    'objectid': 12861,
#    'dc_dist': '15',
#    'psa': '2',
#    'dispatch_date_time': '2019-10-17T01:41:00Z',
#    'dispatch_date': '2019-10-17',
#    'dispatch_time': '01:41:00',
#    'hour_': 1,
#    'dc_key': '201915107271',
#    'location_block': '4300 BLOCK DEVEREAUX AVE',
#    'ucr_general': '200',
#    'text_general_code': 'Rape',
#    'point_x': -75.05840073,
#    'point_y': 40.02300195},
#   {'cartodb_id': 10980,
#    'the_geom': '0101000020E61000003EB25640E3C852C013D8D62EF1FA4340',
#    'the_geom_webmercator': '0101000020110F0000DC76193261E85FC11CC68D714A8A5241',
#    'objectid': 12490,
#    'dc_dist': '6',
#    'psa': '1',
#    'dispatch_date_time': '2020-04-06T23:53:00Z',
#    'dispatch_date': '2020-04-06',
#    'dispatch_time': '23:53:00',
#    'hour_': 23,
#    'dc_key': '202006016870',
#    'location_block': '100 BLOCK SPRING GDN',
#    'ucr_general': '300',
#    'text_general_code': 'Robbery No Firearm',
#    'point_x': -75.13887032,
#    'point_y': 39.96048532},
#   {'cartodb_id': 10981,
#    'the_geom': '0101000020E61000003EB25640E3C852C013D8D62EF1FA4340',
#    'the_geom_webmercator': '0101000020110F0000DC76193261E85FC11CC68D714A8A5241',
#    'objectid': 12491,
#    'dc_dist': '6',
#    'psa': '1',
#    'dispatch_date_time': '2019-06-30T05:25:00Z',
#    'dispatch_date': '2019-06-30',
#    'dispatch_time': '05:25:00',
#    'hour_': 5,
#    'dc_key': '201906031454',
#    'location_block': '600 BLOCK N FRONT ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.13887032,
#    'point_y': 39.96048532},
#   {'cartodb_id': 10982,
#    'the_geom': '0101000020E61000003EB25640E3C852C013D8D62EF1FA4340',
#    'the_geom_webmercator': '0101000020110F0000DC76193261E85FC11CC68D714A8A5241',
#    'objectid': 12492,
#    'dc_dist': '6',
#    'psa': '1',
#    'dispatch_date_time': '2019-08-16T19:48:00Z',
#    'dispatch_date': '2019-08-16',
#    'dispatch_time': '19:48:00',
#    'hour_': 19,
#    'dc_key': '201906041209',
#    'location_block': '600 BLOCK N FRONT ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.13887032,
#    'point_y': 39.96048532},
#   {'cartodb_id': 10983,
#    'the_geom': '0101000020E61000003EB25640E3C852C013D8D62EF1FA4340',
#    'the_geom_webmercator': '0101000020110F0000DC76193261E85FC11CC68D714A8A5241',
#    'objectid': 12493,
#    'dc_dist': '6',
#    'psa': '1',
#    'dispatch_date_time': '2019-09-06T10:46:00Z',
#    'dispatch_date': '2019-09-06',
#    'dispatch_time': '10:46:00',
#    'hour_': 10,
#    'dc_key': '201906045171',
#    'location_block': '600 BLOCK N FRONT ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.13887032,
#    'point_y': 39.96048532},
#   {'cartodb_id': 10984,
#    'the_geom': '0101000020E61000003EB25640E3C852C013D8D62EF1FA4340',
#    'the_geom_webmercator': '0101000020110F0000DC76193261E85FC11CC68D714A8A5241',
#    'objectid': 12494,
#    'dc_dist': '6',
#    'psa': '2',
#    'dispatch_date_time': '2020-02-02T20:32:00Z',
#    'dispatch_date': '2020-02-02',
#    'dispatch_time': '20:32:00',
#    'hour_': 20,
#    'dc_key': '202006006298',
#    'location_block': '200 BLOCK MARKET ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.13887032,
#    'point_y': 39.96048532},
#   {'cartodb_id': 10985,
#    'the_geom': '0101000020E61000003EB25640E3C852C013D8D62EF1FA4340',
#    'the_geom_webmercator': '0101000020110F0000DC76193261E85FC11CC68D714A8A5241',
#    'objectid': 12495,
#    'dc_dist': '6',
#    'psa': '1',
#    'dispatch_date_time': '2020-02-12T19:02:00Z',
#    'dispatch_date': '2020-02-12',
#    'dispatch_time': '19:02:00',
#    'hour_': 19,
#    'dc_key': '202006008189',
#    'location_block': '600 BLOCK N FRONT ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.13887032,
#    'point_y': 39.96048532},
#   {'cartodb_id': 10986,
#    'the_geom': '0101000020E61000003EB25640E3C852C013D8D62EF1FA4340',
#    'the_geom_webmercator': '0101000020110F0000DC76193261E85FC11CC68D714A8A5241',
#    'objectid': 12496,
#    'dc_dist': '6',
#    'psa': '1',
#    'dispatch_date_time': '2020-03-19T13:03:00Z',
#    'dispatch_date': '2020-03-19',
#    'dispatch_time': '13:03:00',
#    'hour_': 13,
#    'dc_key': '202006014885',
#    'location_block': '600 BLOCK N FRONT ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.13887032,
#    'point_y': 39.96048532},
#   {'cartodb_id': 10988,
#    'the_geom': '0101000020E610000056ADF9AF7BC952C0E3D840DBE6FD4340',
#    'the_geom_webmercator': '0101000020110F0000F456AC1F64E95FC164F4981E928D5241',
#    'objectid': 12869,
#    'dc_dist': '26',
#    'psa': '1',
#    'dispatch_date_time': '2019-01-28T16:24:00Z',
#    'dispatch_date': '2019-01-28',
#    'dispatch_time': '16:24:00',
#    'hour_': 16,
#    'dc_key': '201926003861',
#    'location_block': '900 BLOCK DIAMOND ST',
#    'ucr_general': '600',
#    'text_general_code': 'Theft from Vehicle',
#    'point_x': -75.14817428,
#    'point_y': 39.98360768},
#   {'cartodb_id': 11046,
#    'the_geom': '0101000020E6100000E6D09EA295C652C064CF5CAF02004440',
#    'the_geom_webmercator': '0101000020110F000038E466AC77E45FC1C0A8F48BE88F5241',
#    'objectid': 12085,
#    'dc_dist': '24',
#    'psa': '1',
#    'dispatch_date_time': '2019-07-06T14:58:00Z',
#    'dispatch_date': '2019-07-06',
#    'dispatch_time': '14:58:00',
#    'hour_': 14,
#    'dc_key': '201924064129',
#    'location_block': '3600 BLOCK JASPER ST',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.10288301,
#    'point_y': 40.00008194},
#   {'cartodb_id': 11061,
#    'the_geom': '0101000020E6100000A61E92EFCCC652C03EF5401213004440',
#    'the_geom_webmercator': '0101000020110F00007F22689BD5E45FC14939C8B6FA8F5241',
#    'objectid': 12100,
#    'dc_dist': '24',
#    'psa': '1',
#    'dispatch_date_time': '2020-02-12T13:41:00Z',
#    'dispatch_date': '2020-02-12',
#    'dispatch_time': '13:41:00',
#    'hour_': 13,
#    'dc_key': '202024011595',
#    'location_block': '3500 BLOCK KENSINGTON AVE',
#    'ucr_general': '600',
#    'text_general_code': 'Thefts',
#    'point_x': -75.10625829,
#    'point_y': 40.00058201},
#   {'cartodb_id': 11062,
#    'the_geom': '0101000020E6100000A61E92EFCCC652C03EF5401213004440',
#    'the_geom_webmercator': '0101000020110F00007F22689BD5E45FC14939C8B6FA8F5241',
#    'objectid': 12101,
#    'dc_dist': '24',
#    'psa': '1',
#    'dispatch_date_time': '2020-03-11T13:18:00Z',
#    'dispatch_date': '2020-03-11',
#    'dispatch_time': '13:18:00',
#    'hour_': 13,
#    'dc_key': '202024019471',
#    'location_block': '3500 BLOCK KENSINGTON AVE',
#    'ucr_general': '300',
#    'text_general_code': 'Robbery No Firearm',
#    'point_x': -75.10625829,
#    'point_y': 40.00058201},
#   ...],
#  'time': 14.381,
#  'fields': {'cartodb_id': {'type': 'number', 'pgtype': 'int8'},
#   'the_geom': {'type': 'geometry',
#    'wkbtype': 'Unknown',
#    'dims': 2,
#    'srid': 4326},
#   'the_geom_webmercator': {'type': 'geometry',
#    'wkbtype': 'Unknown',
#    'dims': 2,
#    'srid': 3857},
#   'objectid': {'type': 'number', 'pgtype': 'numeric'},
#   'dc_dist': {'type': 'string', 'pgtype': 'text'},
#   'psa': {'type': 'string', 'pgtype': 'text'},
#   'dispatch_date_time': {'type': 'date', 'pgtype': 'timestamp'},
#   'dispatch_date': {'type': 'string', 'pgtype': 'text'},
#   'dispatch_time': {'type': 'string', 'pgtype': 'text'},
#   'hour_': {'type': 'number', 'pgtype': 'numeric'},
#   'dc_key': {'type': 'string', 'pgtype': 'text'},
#   'location_block': {'type': 'string', 'pgtype': 'text'},
#   'ucr_general': {'type': 'string', 'pgtype': 'text'},
#   'text_general_code': {'type': 'string', 'pgtype': 'text'},
#   'point_x': {'type': 'number', 'pgtype': 'numeric'},
#   'point_y': {'type': 'number', 'pgtype': 'numeric'}},
#  'total_rows': 524603}

# %%
#make a dataframe from the JSON

crime_data = pd.DataFrame(loaded['rows'])

# %%
#show the first few rows

crime_data.head()
# Out:
#    cartodb_id                                           the_geom  \
# 0          38  0101000020E610000031D3D5A143C452C07341A64A4E06...
# 1          46  0101000020E6100000CE175A2155CA52C0779E57C02DFB...
# 2          47  0101000020E6100000CE175A2155CA52C0779E57C02DFB...
# 3          91  0101000020E61000007B6EFCE4C3CE52C0F4EC660423F1...
# 4          92  0101000020E61000007B6EFCE4C3CE52C0F4EC660423F1...
#
#                                 the_geom_webmercator  objectid dc_dist psa  \
# 0  0101000020110F0000EEF40FB386E05FC1BAFD11F4E396...        13       9   1
# 1  0101000020110F00009EBBEA78D5EA5FC11055888E8D8A...        21       9   2
# 2  0101000020110F00009EBBEA78D5EA5FC11055888E8D8A...        22       9   2
# 3  0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F...        66      77   A
# 4  0101000020110F00002A2FC7FB5CF25FC12A107CA16E7F...        67      77   A
#
#      dispatch_date_time dispatch_date dispatch_time  hour_        dc_key  \
# 0  2019-11-12T09:59:00Z    2019-11-12      09:59:00    9.0  201909047628
# 1  2019-01-19T17:20:00Z    2019-01-19      17:20:00   17.0  201909002506
# 2  2020-03-25T18:32:00Z    2020-03-25      18:32:00   18.0  202009012094
# 3  2020-03-08T19:08:00Z    2020-03-08      19:08:00   19.0  202077001196
# 4  2020-03-15T18:41:00Z    2020-03-15      18:41:00   18.0  202077001312
#
#                 location_block ucr_general   text_general_code    point_x  \
# 0         100 BLOCK S BROAD ST         600              Thefts -75.066628
# 1  1400 BLOCK SPRING GARDEN ST         600              Thefts -75.161446
# 2  1400 BLOCK SPRING GARDEN ST         600  Theft from Vehicle -75.161446
# 3              0 BLOCK PIA WAY         600              Thefts -75.230706
# 4              0 BLOCK PIA WAY         600              Thefts -75.230706
#
#      point_y
# 0  40.049264
# 1  39.962334
# 2  39.962334
# 3  39.883881
# 4  39.883881

# %%
#figure out the most common crime

crime_data.text_general_code.value_counts()
# Out:
# Thefts                                     87380
# Other Assaults                             85342
# All Other Offenses                         65555
# Vandalism/Criminal Mischief                51325
# Theft from Vehicle                         48069
# Fraud                                      32327
# Motor Vehicle Theft                        22486
# Narcotic / Drug Law Violations             22437
# Aggravated Assault No Firearm              19428
# Burglary Residential                       14323
# Aggravated Assault Firearm                 12662
# Weapon Violations                          11871
# Robbery No Firearm                         10273
# Robbery Firearm                             8565
# Burglary Non-Residential                    7378
# DRIVING UNDER THE INFLUENCE                 6129
# Other Sex Offenses (Not Commercialized)     3179
# Rape                                        2931
# Disorderly Conduct                          2216
# Arson                                       1897
# Receiving Stolen Property                   1351
# Homicide - Criminal                         1323
# Offenses Against Family and Children        1228
# Prostitution and Commercialized Vice        1152
# Recovered Stolen Motor Vehicle              1150
# Embezzlement                                 881
# Forgery and Counterfeiting                   804
# Liquor Law Violations                        336
# Public Drunkenness                           281
# Homicide - Criminal                          187
# Gambling Violations                           95
# Vagrancy/Loitering                            39
# Homicide - Justifiable                         2
# Homicide - Gross Negligence                    1
# Name: text_general_code, dtype: int64
